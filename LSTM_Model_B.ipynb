# %% [markdown]
# #(2) Implement Model B

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 KB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.27.1)
# Collecting huggingface-hub<1.0.0,>=0.11.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 23.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 KB 15.4 MB/s eta 0:00:00
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 KB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.5 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 17.1 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 26.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 16.9 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.10.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multidict, frozenlist, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 datasets-2.11.0 dill-0.3.6 frozenlist-1.3.3 huggingface-hub-0.13.4 multidict-6.0.4 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0 yarl-1.8.2

# %%
import datasets
from datasets import load_dataset
dataset = load_dataset('wmt16', 'de-en')
# Out:
# Downloading builder script:   0%|          | 0.00/2.81k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/18.6k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/9.89k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/41.4k [00:00<?, ?B/s]
# Downloading and preparing dataset wmt16/de-en to /root/.cache/huggingface/datasets/wmt16/de-en/1.0.0/746749a11d25c02058042da7502d973ff410e73457f3d305fc1177dc0e8c4227...
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/658M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/919M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/75.2M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/38.7M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Extracting data files: 0it [00:00, ?it/s]
# Generating train split:   0%|          | 0/4548885 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2169 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2999 [00:00<?, ? examples/s]
# Dataset wmt16 downloaded and prepared to /root/.cache/huggingface/datasets/wmt16/de-en/1.0.0/746749a11d25c02058042da7502d973ff410e73457f3d305fc1177dc0e8c4227. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# !pip install transformers datasets evaluate sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.27.4-py3-none-any.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 60.2 MB/s eta 0:00:00
# Requirement already satisfied: datasets in /usr/local/lib/python3.9/dist-packages (2.11.0)
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 KB 11.3 MB/s eta 0:00:00
# Collecting sacrebleu
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 KB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from sacrebleu) (4.9.2)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.9/dist-packages (from sacrebleu) (0.8.10)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: tokenizers, portalocker, colorama, sacrebleu, transformers, evaluate
# Successfully installed colorama-0.4.6 evaluate-0.4.0 portalocker-2.7.0 sacrebleu-2.3.1 tokenizers-0.13.3 transformers-4.27.4

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from transformers import AutoTokenizer

from transformers import BertTokenizer, BertForSequenceClassification

from datasets import load_dataset
import random
from tqdm import tqdm

# %%
from __future__ import print_function, division
from builtins import range, input
import pickle
import os, sys
import string
import pandas as pd
import re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt


from keras.models import Model
from keras.layers import Input, LSTM, GRU, Dense, Embedding, \
  Bidirectional, RepeatVector, Concatenate, Activation, Dot, Lambda
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

import keras.backend as K
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.optimizers import adam
from keras import optimizers
from sklearn.model_selection import train_test_split

# %matplotlib inline
pd.set_option('display.max_colwidth', 200)

# %%
len(dataset['train'])//1135
# Out:
# 4007

# %%
gr_train=[]
en_train=[]
for i in tqdm(range(0,len(dataset['train'])//1135)): 
   gr_train.append(dataset['train'][i]['translation']['de'])
   en_train.append(dataset['train'][i]['translation']['en'])
# Out:
# 100%|██████████| 4007/4007 [00:00<00:00, 5268.28it/s]

# %%
gr_val=[]
en_val=[]
for i in tqdm(range(0,len(dataset['validation']))): 
   gr_val.append(dataset['validation'][i]['translation']['de'])
   en_val.append(dataset['validation'][i]['translation']['en'])
# Out:
# 100%|██████████| 2169/2169 [00:00<00:00, 2685.41it/s]

# %%
gr_test=[]
en_test=[]
for i in tqdm(range(0,len(dataset['test']))): 
   gr_test.append(dataset['test'][i]['translation']['de'])
   en_test.append(dataset['test'][i]['translation']['en'])
# Out:
# 100%|██████████| 2999/2999 [00:00<00:00, 4492.52it/s]

# %% [markdown]
# Merging train & validation for efficient & sequencial loading into batch

# %%
# 4548 +2169 = 6176
# do not run this cell twice
gr_train = gr_train + gr_val
en_train = en_train + en_val
print(len(gr_train))
# Out:
# 6176

# %% [markdown]
# ## Model Configurations

# %%
# config
BATCH_SIZE = 2
EPOCHS = 10
LATENT_DIM = 64
LATENT_DIM_DECODER = 64 
EMBEDDING_DIM = 50

# %%
input_texts = [] # English sentences
target_texts = [] # German sentences
target_texts_inputs = []# German sentences offset by 1 for teacher forcing

#Converting to lowercase
gr_train=[line.lower() for line in gr_train]
en_train=[line.lower() for line in en_train]
NUM_SAMPLES=len(gr_train)
print("Sample train size:",len(en_train))
# Out:
# Sample train size: 6176

# %% [markdown]
# ##Preprocess

# %% [markdown]
# ### Preprocess Training + Validation data

# %%
#Adding <sos> and <eos> tokens

# for lines in en_train:
for lines in gr_train:
    target_texts_inputs.append('<sos>'+" "+ lines)
    
# for lines in en_train:
for lines in gr_train:
    target_texts.append(lines+ " " +'<eos>')
    
# for lines in gr_train:
for lines in en_train:
    input_texts.append(lines)

# %%
# tokenize English sentences
tokenizer_inputs = Tokenizer()
tokenizer_inputs.fit_on_texts(input_texts)
input_sequences = tokenizer_inputs.texts_to_sequences(input_texts)

# word to index mapping for English
word2idx_inputs = tokenizer_inputs.word_index

# Max length of English sentence
max_len_input = max(len(s) for s in input_sequences)
max_len_input = 6

#tokenize German sentences
tokenizer_outputs = Tokenizer(filters='')
tokenizer_outputs.fit_on_texts(target_texts + target_texts_inputs) 
target_sequences = tokenizer_outputs.texts_to_sequences(target_texts)
target_sequences_inputs = tokenizer_outputs.texts_to_sequences(target_texts_inputs)

# Word to index mapping for German
word2idx_outputs = tokenizer_outputs.word_index

# store number of output words for later
num_words_output = len(word2idx_outputs) + 1

# Max length of German sentence
max_len_target = max(len(s) for s in target_sequences)
max_len_target = 6

# pad the sequences
encoder_inputs = pad_sequences(input_sequences, maxlen=max_len_input)
decoder_inputs = pad_sequences(target_sequences_inputs, maxlen=max_len_target, padding='post')
decoder_targets = pad_sequences(target_sequences, maxlen=max_len_target, padding='post')

print('Data Preprocessed')
print("Max train English sentence length:", max_len_target)
print("Max train German sentence length:", max_len_input)
print("Unique German Vocabulary count:",len(word2idx_inputs))
print("Unique English Vocabulary count:",len(word2idx_outputs))
# Out:
# Data Preprocessed
# Max train English sentence length: 6
# Max train German sentence length: 6
# Unique German Vocabulary count: 11448
# Unique English Vocabulary count: 22994

# %% [markdown]
# ###Preprocess Test Data

# %%
##Test Preparation
input_texts_test = [] # English sentences
target_texts_test = [] # German sentences
target_texts_inputs_test = []# German sentences offset by 1 for teacher forcing

#Converting to lowercase
gr_test=[line.lower() for line in gr_test]
en_test=[line.lower() for line in en_test]

# %%
#Adding <sos> and <eos> tokens

for lines in gr_test:
    target_texts_inputs_test.append('<sos>'+" "+ lines)
    
for lines in gr_test:
    target_texts_test.append(lines+ " " +'<eos>')
    
for lines in en_test:
    input_texts_test.append(lines)

# %%
print(target_texts_test[0])
target_texts_inputs_test[0]
# Out:
# obama empfängt netanyahu <eos>
# '<sos> obama empfängt netanyahu'

# %%
# tokenize English sentences

input_sequences_test = tokenizer_inputs.texts_to_sequences(input_texts_test)


target_sequences_test = tokenizer_outputs.texts_to_sequences(target_texts_test)
target_sequences_inputs_test = tokenizer_outputs.texts_to_sequences(target_texts_inputs_test)

# pad the sequences
encoder_inputs_test = pad_sequences(input_sequences_test, maxlen=max_len_input)
decoder_inputs_test = pad_sequences(target_sequences_inputs_test, maxlen=max_len_target, padding='post')
decoder_targets_test = pad_sequences(target_sequences_test, maxlen=max_len_target, padding='post')

print("Max test English sentence length:", decoder_inputs_test.shape[1])
print("Max test German sentence length:", encoder_inputs_test.shape[1])
# Out:
# Max test English sentence length: 6
# Max test German sentence length: 6

# %% [markdown]
# ###Embedding

# %%
# download glove and unzip it in Notebook.
# !wget http://nlp.stanford.edu/data/glove.6B.zip
#!unzip glove*.zip

# %% [markdown]
# ## GloVe Embedding

# %%
#Load pretrained word vectors from Glove
print('Loading word vectors...')
word2vec = {}

#/content/drive/MyDrive/2 Sem/DL/Assignments/A3_BharatGoyal_DebnathKundu_SaloniAgrawal/Q2/glove.6B/glove.6B.50d.txt
#/content/drive/MyDrive/2 Sem/DL/Assignments/A3_BharatGoyal_DebnathKundu_SaloniAgrawal/Q2/subs.de.vec
#/content/drive/MyDrive/2 Sem/DL/Assignments/A3_BharatGoyal_DebnathKundu_SaloniAgrawal/Q2/glove.6B/glove.6B.100d.txt
with open(os.path.join('/content/drive/MyDrive/2 Sem/DL/Assignments/A3_BharatGoyal_DebnathKundu_SaloniAgrawal/Q2/glove.6B/glove.6B.100d.txt'), encoding="utf8") as f:
  # is just a space-separated text file in the format:
  # word vec[0] vec[1] vec[2] ...
  for line in f:
    values = line.split()
    word = values[0]
    vec = np.asarray(values[1:], dtype='float32')
    word2vec[word] = vec
print('Found %s word vectors.' % len(word2vec))
# Out:
# Loading word vectors...
# Found 400000 word vectors.

# %%
EMBEDDING_DIM=100
# prepare embedding matrix
print('Filling pre-trained embeddings...')
num_words=len(word2idx_inputs) + 1 #English vocab count+1
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word2idx_inputs.items():
  if i < num_words:
    embedding_vector = word2vec.get(word)
    if embedding_vector is not None:
      # words not found in embedding index will be all zeros.
      embedding_matrix[i] = embedding_vector
# Out:
# Filling pre-trained embeddings...

# %%
embedding_matrix[89]
# Out:
# array([-1.78639993e-01,  1.49169996e-01,  5.12189984e-01, -2.84119993e-01,
#         6.22409999e-01,  7.78639972e-01, -6.16559992e-03,  7.72970021e-02,
#         2.49870002e-01,  9.02170017e-02, -1.06880002e-01,  3.84860009e-01,
#        -9.19039994e-02,  6.36150002e-01,  2.41280004e-01, -2.27149993e-01,
#         3.35359991e-01,  5.08029997e-01, -2.78389990e-01, -4.37779993e-01,
#         5.71139991e-01,  5.94850004e-01,  8.11209977e-01,  1.94389999e-01,
#         2.56630003e-01, -1.71579998e-02, -2.64030010e-01, -3.65310013e-01,
#         7.23109990e-02,  1.34059995e-01, -1.59229994e-01,  4.64749992e-01,
#        -4.95860010e-01, -4.36650008e-01, -7.87239969e-02,  1.17470004e-01,
#        -7.22479969e-02,  1.72920004e-01, -2.49770001e-01,  6.66100008e-04,
#        -6.62989974e-01, -7.91779995e-01, -4.90810007e-01, -2.01949999e-01,
#         4.14520018e-02,  5.23859978e-01, -3.47059995e-01,  5.53730011e-01,
#         3.66100013e-01, -3.25760007e-01, -4.32020009e-01,  3.18980008e-01,
#         2.12980002e-01,  1.34739995e+00, -2.80750006e-01, -3.05159998e+00,
#        -1.69039994e-01, -4.86030012e-01,  2.51539993e+00,  7.06319988e-01,
#         8.92120004e-02,  1.41630006e+00,  7.22199976e-02,  5.48759997e-01,
#         8.36809993e-01, -3.19559984e-02,  3.49909991e-01, -8.93929973e-02,
#        -2.59609997e-01,  2.18540011e-03,  1.94140002e-01, -5.61129987e-01,
#        -2.77089998e-02, -8.60589981e-01, -1.44970000e-01, -1.21710002e-01,
#        -3.90960008e-01, -2.53630012e-01, -6.60440028e-01,  1.22620001e-01,
#         7.85690010e-01,  7.20309973e-01, -7.32500017e-01,  4.32280004e-01,
#        -9.32539999e-01, -8.83809999e-02, -1.04259998e-01, -3.40270013e-01,
#        -2.88729995e-01, -4.13700014e-01, -3.41370003e-03,  2.07580000e-01,
#        -9.30729985e-01,  3.10369998e-01, -1.40080005e-01, -4.49649990e-01,
#         2.12970003e-01,  3.14810008e-01,  5.24489999e-01,  1.55220002e-01])

# %% [markdown]
# ##Creating the Model

# %% [markdown]
# Define Softmax Activation Function

# %%
def softmax_over_time(x):
  assert(K.ndim(x) > 2)
  e = K.exp(x - K.max(x, axis=1, keepdims=True))
  s = K.sum(e, axis=1, keepdims=True)
  return e / s

# %% [markdown]
# Define Embedding Layer

# %%
# create embedding layer
embedding_layer = Embedding(
  num_words,
  EMBEDDING_DIM,
  weights=[embedding_matrix],
  input_length=max_len_input,
  # trainable=True
)

# %% [markdown]
# One-hot Encoding

# %%
decoder_targets_one_hot = np.zeros(
  (
    len(input_texts),
    max_len_target,
    num_words_output
  ),
  dtype='float32'
)

# assign the values
for i, d in enumerate(decoder_targets):
  for t, word in enumerate(d):
    decoder_targets_one_hot[i, t, word] = 1

# %% [markdown]
# Define Encoding Layer

# %%
#encoder
encoder_inputs_placeholder = Input(shape=(max_len_input,))
x = embedding_layer(encoder_inputs_placeholder)
encoder = Bidirectional(LSTM(
  LATENT_DIM,
  return_sequences=True, dropout=0.2
))
encoder_outputs = encoder(x)

# %% [markdown]
# Define Decoder Layer

# %%
#Decoder
decoder_inputs_placeholder = Input(shape=(max_len_target,))
decoder_embedding = Embedding(num_words_output, EMBEDDING_DIM)
decoder_inputs_x = decoder_embedding(decoder_inputs_placeholder)

# %% [markdown]
# ###Define Attention Layers

# %%
#Attention
attn_repeat_layer = RepeatVector(max_len_input)
attn_concat_layer = Concatenate(axis=-1)
attn_dense1 = Dense(3, activation='tanh') #10
attn_dense2 = Dense(1, activation=softmax_over_time)

attn_dot = Dot(axes=1) # to perform the weighted sum of alpha[t] * h[t]

# %%
def one_step_attention(h, st_1):
  # h = h(1), ..., h(Tx), shape = (Tx, LATENT_DIM * 2)
  # st_1 = s(t-1), shape = (LATENT_DIM_DECODER,)
 
  # copy s(t-1) Tx times
  # now shape = (Tx, LATENT_DIM_DECODER)
  st_1 = attn_repeat_layer(st_1)

  # Concatenate all h(t)'s with s(t-1)
  # Now of shape (Tx, LATENT_DIM_DECODER + LATENT_DIM * 2)
  x = attn_concat_layer([h, st_1])

  # Neural net first layer
  x = attn_dense1(x)

  # Neural net second layer with special softmax over time
  alphas = attn_dense2(x)

  # "Dot" the alphas and the h's
  # Remember a.dot(b) = sum over a[t] * b[t]
  context = attn_dot([alphas, h])

  return context

# %%
# define the rest of the decoder (after attention)
decoder_lstm = LSTM(LATENT_DIM_DECODER, return_state=True)
decoder_dense = Dense(num_words_output, activation='softmax')

initial_s = Input(shape=(LATENT_DIM_DECODER,), name='s0')
initial_c = Input(shape=(LATENT_DIM_DECODER,), name='c0')
context_last_word_concat_layer = Concatenate(axis=2)

# %%
# s, c will be re-assigned in each iteration of the loop
s = initial_s
c = initial_c

# collect outputs in a list at first
outputs = []
for t in tqdm(range(max_len_target)): # Ty times
  # get the context using attention
  context = one_step_attention(encoder_outputs, s)

  # we need a different layer for each time step
  selector = Lambda(lambda x: x[:, t:t+1])
  xt = selector(decoder_inputs_x)
  
  # combine 
  decoder_lstm_input = context_last_word_concat_layer([context, xt])

  # pass the combined [context, last word] into the LSTM
  # along with [s, c]
  # get the new [s, c] and output
  o, s, c = decoder_lstm(decoder_lstm_input, initial_state=[s, c])

  # final dense layer to get next word prediction
  decoder_outputs = decoder_dense(o)
  outputs.append(decoder_outputs)
# Out:
# 100%|██████████| 6/6 [00:02<00:00,  2.69it/s]

# %%
def stack_and_transpose(x):
  # x is a list of length T, each element is a batch_size x output_vocab_size tensor
  x = K.stack(x) # is now T x batch_size x output_vocab_size tensor
  x = K.permute_dimensions(x, pattern=(1, 0, 2)) # is now batch_size x T x output_vocab_size
  return x

# make it a layerx``
stacker = Lambda(stack_and_transpose)
outputs = stacker(outputs)

# %%
# create the model
model = Model(
  inputs=[
    encoder_inputs_placeholder,
    decoder_inputs_placeholder,
    initial_s, 
    initial_c,
  ],
  outputs=outputs
)

# %% [markdown]
# ##Model Training

# %%
learning_rate=0.001
# checkpoint
filepath="german_eng_finalmodel"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# compile the model

model.compile(optimizer=optimizers.Adam(learning_rate) ,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 6)]          0           []
#
#  embedding (Embedding)          (None, 6, 100)       1144900     ['input_1[0][0]']
#
#  s0 (InputLayer)                [(None, 64)]         0           []
#
#  bidirectional (Bidirectional)  (None, 6, 128)       84480       ['embedding[0][0]']
#
#  repeat_vector (RepeatVector)   (None, 6, 64)        0           ['s0[0][0]',
#                                                                   'lstm_1[0][1]',
#                                                                   'lstm_1[1][1]',
#                                                                   'lstm_1[2][1]',
#                                                                   'lstm_1[3][1]',
#                                                                   'lstm_1[4][1]']
#
#  concatenate (Concatenate)      (None, 6, 192)       0           ['bidirectional[0][0]',
#                                                                   'repeat_vector[0][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[1][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[2][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[3][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[4][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'repeat_vector[5][0]']
#
#  dense (Dense)                  (None, 6, 3)         579         ['concatenate[0][0]',
#                                                                   'concatenate[1][0]',
#                                                                   'concatenate[2][0]',
#                                                                   'concatenate[3][0]',
#                                                                   'concatenate[4][0]',
#                                                                   'concatenate[5][0]']
#
#  input_2 (InputLayer)           [(None, 6)]          0           []
#
#  dense_1 (Dense)                (None, 6, 1)         4           ['dense[0][0]',
#                                                                   'dense[1][0]',
#                                                                   'dense[2][0]',
#                                                                   'dense[3][0]',
#                                                                   'dense[4][0]',
#                                                                   'dense[5][0]']
#
#  embedding_1 (Embedding)        (None, 6, 100)       2299500     ['input_2[0][0]']
#
#  dot (Dot)                      (None, 1, 128)       0           ['dense_1[0][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[1][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[2][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[3][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[4][0]',
#                                                                   'bidirectional[0][0]',
#                                                                   'dense_1[5][0]',
#                                                                   'bidirectional[0][0]']
#
#  lambda (Lambda)                (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 1, 228)       0           ['dot[0][0]',
#                                                                   'lambda[0][0]',
#                                                                   'dot[1][0]',
#                                                                   'lambda_1[0][0]',
#                                                                   'dot[2][0]',
#                                                                   'lambda_2[0][0]',
#                                                                   'dot[3][0]',
#                                                                   'lambda_3[0][0]',
#                                                                   'dot[4][0]',
#                                                                   'lambda_4[0][0]',
#                                                                   'dot[5][0]',
#                                                                   'lambda_5[0][0]']
#
#  c0 (InputLayer)                [(None, 64)]         0           []
#
#  lstm_1 (LSTM)                  [(None, 64),         75008       ['concatenate_1[0][0]',
#                                  (None, 64),                      's0[0][0]',
#                                  (None, 64)]                      'c0[0][0]',
#                                                                   'concatenate_1[1][0]',
#                                                                   'lstm_1[0][1]',
#                                                                   'lstm_1[0][2]',
#                                                                   'concatenate_1[2][0]',
#                                                                   'lstm_1[1][1]',
#                                                                   'lstm_1[1][2]',
#                                                                   'concatenate_1[3][0]',
#                                                                   'lstm_1[2][1]',
#                                                                   'lstm_1[2][2]',
#                                                                   'concatenate_1[4][0]',
#                                                                   'lstm_1[3][1]',
#                                                                   'lstm_1[3][2]',
#                                                                   'concatenate_1[5][0]',
#                                                                   'lstm_1[4][1]',
#                                                                   'lstm_1[4][2]']
#
#  lambda_1 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_2 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_4 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 1, 100)       0           ['embedding_1[0][0]']
#
#  dense_2 (Dense)                (None, 22995)        1494675     ['lstm_1[0][0]',
#                                                                   'lstm_1[1][0]',
#                                                                   'lstm_1[2][0]',
#                                                                   'lstm_1[3][0]',
#                                                                   'lstm_1[4][0]',
#                                                                   'lstm_1[5][0]']
#
#  lambda_6 (Lambda)              (None, 6, 22995)     0           ['dense_2[0][0]',
#                                                                   'dense_2[1][0]',
#                                                                   'dense_2[2][0]',
#                                                                   'dense_2[3][0]',
#                                                                   'dense_2[4][0]',
#                                                                   'dense_2[5][0]']
#
# ==================================================================================================
# Total params: 5,099,146
# Trainable params: 5,099,146
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from keras.utils import plot_model

plot_model(model, to_file='model_trn_plot.png', show_shapes=True, show_layer_names=True)

# %%
EPOCHS = 12

# train the model
z = np.zeros((encoder_inputs.shape[0], LATENT_DIM_DECODER)) # initial [s, c]
r = model.fit(
  [encoder_inputs, decoder_inputs, z, z], decoder_targets_one_hot,
  batch_size=BATCH_SIZE,
  epochs=EPOCHS,
  validation_split=0.25,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/12
# 2315/2316 [============================>.] - ETA: 0s - loss: 7.0855 - accuracy: 0.1896
# Epoch 1: val_accuracy improved from -inf to 0.19905, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 110s 41ms/step - loss: 7.0856 - accuracy: 0.1896 - val_loss: 7.0726 - val_accuracy: 0.1991
# Epoch 2/12
# 2314/2316 [============================>.] - ETA: 0s - loss: 5.8789 - accuracy: 0.2244
# Epoch 2: val_accuracy improved from 0.19905 to 0.20974, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 83s 36ms/step - loss: 5.8788 - accuracy: 0.2243 - val_loss: 7.5321 - val_accuracy: 0.2097
# Epoch 3/12
# 2315/2316 [============================>.] - ETA: 0s - loss: 5.4484 - accuracy: 0.2431
# Epoch 3: val_accuracy improved from 0.20974 to 0.22215, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 82s 35ms/step - loss: 5.4481 - accuracy: 0.2431 - val_loss: 7.9191 - val_accuracy: 0.2222
# Epoch 4/12
# 2315/2316 [============================>.] - ETA: 0s - loss: 5.0967 - accuracy: 0.2580
# Epoch 4: val_accuracy improved from 0.22215 to 0.22528, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 77s 33ms/step - loss: 5.0961 - accuracy: 0.2581 - val_loss: 8.0170 - val_accuracy: 0.2253
# Epoch 5/12
# 2316/2316 [==============================] - ETA: 0s - loss: 4.7604 - accuracy: 0.2758
# Epoch 5: val_accuracy improved from 0.22528 to 0.23068, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 79s 34ms/step - loss: 4.7604 - accuracy: 0.2758 - val_loss: 8.1042 - val_accuracy: 0.2307
# Epoch 6/12
# 2314/2316 [============================>.] - ETA: 0s - loss: 4.4330 - accuracy: 0.2943
# Epoch 6: val_accuracy improved from 0.23068 to 0.23424, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 78s 34ms/step - loss: 4.4329 - accuracy: 0.2943 - val_loss: 8.2110 - val_accuracy: 0.2342
# Epoch 7/12
# 2315/2316 [============================>.] - ETA: 0s - loss: 4.1263 - accuracy: 0.3140
# Epoch 7: val_accuracy improved from 0.23424 to 0.23748, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 74s 32ms/step - loss: 4.1267 - accuracy: 0.3139 - val_loss: 8.2469 - val_accuracy: 0.2375
# Epoch 8/12
# 2316/2316 [==============================] - ETA: 0s - loss: 3.8442 - accuracy: 0.3331
# Epoch 8: val_accuracy improved from 0.23748 to 0.24493, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 74s 32ms/step - loss: 3.8442 - accuracy: 0.3331 - val_loss: 8.2553 - val_accuracy: 0.2449
# Epoch 9/12
# 2316/2316 [==============================] - ETA: 0s - loss: 3.5738 - accuracy: 0.3583
# Epoch 9: val_accuracy improved from 0.24493 to 0.24557, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 79s 34ms/step - loss: 3.5738 - accuracy: 0.3583 - val_loss: 8.3298 - val_accuracy: 0.2456
# Epoch 10/12
# 2316/2316 [==============================] - ETA: 0s - loss: 3.3165 - accuracy: 0.3899
# Epoch 10: val_accuracy improved from 0.24557 to 0.24709, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 80s 34ms/step - loss: 3.3165 - accuracy: 0.3899 - val_loss: 8.3318 - val_accuracy: 0.2471
# Epoch 11/12
# 2316/2316 [==============================] - ETA: 0s - loss: 3.0795 - accuracy: 0.4252
# Epoch 11: val_accuracy improved from 0.24709 to 0.24773, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 79s 34ms/step - loss: 3.0795 - accuracy: 0.4252 - val_loss: 8.3580 - val_accuracy: 0.2477
# Epoch 12/12
# 2314/2316 [============================>.] - ETA: 0s - loss: 2.8558 - accuracy: 0.4620
# Epoch 12: val_accuracy improved from 0.24773 to 0.24946, saving model to german_eng_finalmodel
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# 2316/2316 [==============================] - 78s 34ms/step - loss: 2.8556 - accuracy: 0.4620 - val_loss: 8.3882 - val_accuracy: 0.2495

# %% [markdown]
# ##Graphs

# %%
print("Train loss: ",r.history['loss'])
print("Validation loss: ",r.history['val_loss'])
# Out:
# Train loss:  [7.085570812225342, 5.878804683685303, 5.448145389556885, 5.096138954162598, 4.760441780090332, 4.432870388031006, 4.126713275909424, 3.844189405441284, 3.5737874507904053, 3.3164875507354736, 3.0794506072998047, 2.8556056022644043]
# Validation loss:  [7.072648048400879, 7.532124042510986, 7.919065952301025, 8.01704216003418, 8.104242324829102, 8.210969924926758, 8.246892929077148, 8.255257606506348, 8.329833984375, 8.331792831420898, 8.35798454284668, 8.38824462890625]

# %%
val_loss=r.history['val_loss']
print(val_loss)
val_loss.reverse()
print(val_loss)
# Out:
# [7.072648048400879, 7.532124042510986, 7.919065952301025, 8.01704216003418, 8.104242324829102, 8.210969924926758, 8.246892929077148, 8.255257606506348, 8.329833984375, 8.331792831420898, 8.35798454284668, 8.38824462890625]
# [8.38824462890625, 8.35798454284668, 8.331792831420898, 8.329833984375, 8.255257606506348, 8.246892929077148, 8.210969924926758, 8.104242324829102, 8.01704216003418, 7.919065952301025, 7.532124042510986, 7.072648048400879]

# %%
# plot loss
# plt.plot(r.history['val_loss'], label='val_loss')

plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val_loss')

plt.legend()
plt.show()

# %%
print("Train accuracy: ",r.history['accuracy'])
print("Validation accuracy: ",r.history['val_accuracy'])
# Out:
# Train accuracy:  [0.18958693742752075, 0.2243451327085495, 0.24312752485275269, 0.25805985927581787, 0.27576279640197754, 0.2942933142185211, 0.313903272151947, 0.33308145403862, 0.3582685589790344, 0.38989636301994324, 0.4252302944660187, 0.46196746826171875]
# Validation accuracy:  [0.19905008375644684, 0.20973661541938782, 0.2221502661705017, 0.22528065741062164, 0.23067788779735565, 0.2342400699853897, 0.23747840523719788, 0.2449266016483307, 0.24557426571846008, 0.24708549678325653, 0.24773316085338593, 0.24946027994155884]

# %%
# accuracies
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()

# %% [markdown]
# ##Modifying the model for Predictions

# %%
encoder_model = Model(encoder_inputs_placeholder, encoder_outputs)

# next we define a T=1 decoder model
encoder_outputs_as_input = Input(shape=(max_len_input, LATENT_DIM * 2,))
decoder_inputs_single = Input(shape=(1,))
decoder_inputs_single_x = decoder_embedding(decoder_inputs_single)

# no need to loop over attention steps this time because there is only one step
context = one_step_attention(encoder_outputs_as_input, initial_s)

# combine context with last word
decoder_lstm_input = context_last_word_concat_layer([context, decoder_inputs_single_x])

# lstm and final dense
o, s, c = decoder_lstm(decoder_lstm_input, initial_state=[initial_s, initial_c])
decoder_outputs = decoder_dense(o)

# %%
# create the model object
decoder_model = Model(
  inputs=[
    decoder_inputs_single,
    encoder_outputs_as_input,
    initial_s, 
    initial_c
  ],
  outputs=[decoder_outputs, s, c]
)

# %%
decoder_model.save("enfr_decoder_model.h5")
encoder_model.save("enfr_encoder_model.h5")
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# ##Making Predictions

# %%
idx2word_eng = {v:k for k, v in word2idx_inputs.items()}
idx2word_trans = {v:k for k, v in word2idx_outputs.items()}

# %%
import pickle
pickle.dump( idx2word_eng, open( "idx2word_eng1.pkl", "wb" ) )
pickle.dump(idx2word_trans,open("idx2word_fr.pkl","wb"))
pickle.dump(tokenizer_inputs,open("tokenizer_inputs.pkl","wb"))

# %%
def decode_sequence(input_seq):
  # Encode the input as state vectors.
  enc_out = encoder_model.predict(input_seq)

  # Generate empty target sequence of length 1.
  target_seq = np.zeros((1, 1))
  
  # Populate the first character of target sequence with the start character.
  # NOTE: tokenizer lower-cases all words
  target_seq[0, 0] = word2idx_outputs['<sos>']

  # if we get this we break
  eos = word2idx_outputs['<eos>']


  # [s, c] will be updated in each loop iteration
  s = np.zeros((1, LATENT_DIM_DECODER))
  c = np.zeros((1, LATENT_DIM_DECODER))


  # Create the translation
  output_sentence = []
  for _ in range(max_len_target):
    o, s, c = decoder_model.predict([target_seq, enc_out, s, c])
        

    # Get next word
    idx = np.argmax(o.flatten())

    # End sentence of EOS
    if eos == idx:
      break

    word = ''
    if idx > 0:
      word = idx2word_trans[idx]
      output_sentence.append(word)

    # Update the decoder input
    # which is just the word just generated
    target_seq[0, 0] = idx

  return ' '.join(output_sentence)

# %% [markdown]
# ##Testing the model

# %%
test_actual_sentence=[]
test_predicted_sentence=[]

for i in range(len(en_test)//6):
    # Do some test translations
  
  input_seq = encoder_inputs_test[i:i+1]
  translation = decode_sequence(input_seq)

  test_actual_sentence.append(target_texts_test[i])
  test_predicted_sentence.append(translation)
  print("..........................................")
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 472ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# ..........................................
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# ..........................................
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# ..........................................
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# ..........................................
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# ..........................................
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# ..........................................
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# ..........................................
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# ..........................................
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 42ms/step
# ..........................................
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# ..........................................
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# ..........................................
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# ..........................................
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# ..........................................
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 32ms/step
# ..........................................
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# ..........................................
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# ..........................................
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 42ms/step
# ..........................................
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# ..........................................
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# ..........................................
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# ..........................................
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# ..........................................
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# ..........................................
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# ..........................................
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# ..........................................
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# ..........................................
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# ..........................................
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# ..........................................
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# ..........................................
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# ..........................................
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# ..........................................
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# ..........................................
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# ..........................................
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# ..........................................
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# ...
# 1/1 [==============================] - 0s 37ms/step
# ..........................................
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# ..........................................
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 54ms/step
# ..........................................
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# ..........................................
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# ..........................................
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 54ms/step
# ..........................................
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# ..........................................
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# ..........................................
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# ..........................................
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# ..........................................
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 53ms/step
# ..........................................
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# ..........................................
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# ..........................................
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 38ms/step
# ..........................................
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# ..........................................
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 75ms/step
# ..........................................
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# ..........................................
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# ..........................................
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# ..........................................
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# ..........................................
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# ..........................................
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# ..........................................
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 24ms/step
# ..........................................
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# ..........................................

# %%
#printing some sample predictions

for i in range(0,50):
    print('-')
    print('Input sentence:', input_texts_test[i])
    print('Predicted translation:', test_predicted_sentence[i])
    print('Actual translation:', target_texts_test[i])
# Out:
# -
# Input sentence: obama receives netanyahu
# Predicted translation: bericht ist ist herr niveau.
# Actual translation: obama empfängt netanyahu <eos>
# -
# Input sentence: the relationship between obama and netanyahu is not exactly friendly.
# Predicted translation: das das noch gar vorliegt.
# Actual translation: das verhältnis zwischen obama und netanyahu ist nicht gerade freundschaftlich. <eos>
# -
# Input sentence: the two wanted to talk about the implementation of the international agreement and about teheran's destabilising activities in the middle east.
# Predicted translation: in verlaufe der ländlichen hinaus.
# Actual translation: die beiden wollten über die umsetzung der internationalen vereinbarung sowie über teherans destabilisierende maßnahmen im nahen osten sprechen. <eos>
# -
# Input sentence: the meeting was also planned to cover the conflict with the palestinians and the disputed two state solution.
# Predicted translation: und regionen und zu verbergen.
# Actual translation: bei der begegnung soll es aber auch um den konflikt mit den palästinensern und die diskutierte zwei-staaten-lösung gehen. <eos>
# -
# Input sentence: relations between obama and netanyahu have been strained for years.
# Predicted translation: eine einen zu zu hinaus.
# Actual translation: das verhältnis zwischen obama und netanyahu ist seit jahren gespannt. <eos>
# -
# Input sentence: washington criticises the continuous building of settlements in israel and accuses netanyahu of a lack of initiative in the peace process.
# Predicted translation: der den der ländlichen einlösten.
# Actual translation: washington kritisiert den andauernden siedlungsbau israels und wirft netanyahu mangelnden willen beim friedensprozess vor. <eos>
# -
# Input sentence: the relationship between the two has further deteriorated because of the deal that obama negotiated on iran's atomic programme, .
# Predicted translation: nur einen zum 0,2 er.
# Actual translation: durch den von obama beworbenen deal um das iranische atomprogramm hat sich die beziehung der beiden weiter verschlechtert. <eos>
# -
# Input sentence: in march, at the invitation of the republicans, netanyahu made a controversial speech to the us congress, which was partly seen as an affront to obama.
# Predicted translation: eine einen einen mal gegangen.
# Actual translation: im märz hatte netanyahu auf einladung der republikaner vor dem us-kongress eine umstrittene rede gehalten, die teils als affront gegen obama gewertet wurde. <eos>
# -
# Input sentence: the speech had not been agreed with obama, who had rejected a meeting with reference to the election that was at that time impending in israel.
# Predicted translation: das eine eine zu gegangen.
# Actual translation: die rede war mit obama nicht abgesprochen, ein treffen hatte dieser mit hinweis auf die seinerzeit bevorstehende wahl in israel abgelehnt. <eos>
# -
# Input sentence: in 911 call, professor admits to shooting girlfriend
# Predicted translation: mit einen und einem hinaus.
# Actual translation: in einem notruf gesteht professor, seine freundin erschossen zu haben <eos>
# -
# Input sentence: in a 911 call, his voice only slightly shaky, college professor shannon lamb told police he had shot his girlfriend and officers needed to get over to their house.
# Predicted translation: die diesem einen zeit gegangen.
# Actual translation: in einem notruf erzählte professor shannon lamb mit einer etwas zittrigen stimme der polizei, dass er seine freundin erschossen habe und dass die beamten zu seinem haus kommen müssten. <eos>
# -
# Input sentence: lamb made a point to say his "sweet dog" was there alive and probably upset, and said the dead woman's family contacts could be found on her phone.
# Predicted translation: lassen mit eine jemenitische hinaus.
# Actual translation: lamb war es wichtig zu betonen, dass sein "süßer hund" aber noch lebe und wahrscheinlich aufgeregt sei, und er sagte, die familienkontakte der toten frau könnten auf dem handy gefunden werden. <eos>
# -
# Input sentence: inside the home, officers found amy prentiss' body and a hand-written note scribbled on a white legal pad: "i am so very sorry i wish i could take it back i loved amy and she is the only woman who ever loved me," read the letter authorities say was signed by lamb.
# Predicted translation: ihn eine eine besonders hinaus.
# Actual translation: innerhalb des hauses fanden die beamten die leiche von amy prentiss und eine handgeschriebene notiz, die auf einen weißen block gekritzelt war: "mir tut es so leid, ich wollte, ich könnte es rückgängig machen, ich liebte amy und sie ist die einzige frau, die mich jemals liebte". dies stand nach angaben der behörden in dem brief, und er war von lamb unterzeichnet. <eos>
# -
# Input sentence: there was no indication that lamb, who was teaching two online classes for delta state university in cleveland, mississippi, had already traveled 300 miles to the school's campus, where police believe he shot and killed a well-liked history professor, ethan schmidt, in the doorway to his office.
# Predicted translation: der einen im erschienenen mißbilligen.
# Actual translation: es gab keinen hinweis darauf, dass lamb, der in zwei online-kursen für die delta state university in cleveland, mississippi, unterrichtete, bereits 300 meilen zu dem schulgelände gereist war, wo er nach angaben der polizei einen beliebten geschichtsprofessor, ethan schmidt, an der tür zu seinem büro erschossen und getötet hat. <eos>
# -
# Input sentence: delta state university police chief lynn buford said university officials heard about the shooting at 10:18 a.m.
# Predicted translation: um um schwarzen uhr geschrumpft
# Actual translation: delta state university polizeichef lynn buford sagte, dass universitäts-mitarbeiter das schießen um 10:18 uhr gehört haben. <eos>
# -
# Input sentence: he said lamb made the fateful 911 call sometime after that.
# Predicted translation: im einen ein erschienenen kämpfen.
# Actual translation: er sagte, dass lamb den verhängnisvollen notruf irgendwann danach gemacht hat. <eos>
# -
# Input sentence: by the end of the day, there would be one more death: lamb took his own life as police closed in on him.
# Predicted translation: in über den zu verbergen.
# Actual translation: bis zum ende des tages gab es einen weiteren tod: lamm nahm sich das leben, als die polizei ihn einkesselte. <eos>
# -
# Input sentence: a day after the school shooting forced students and faculty to hide behind locked doors, authorities were still trying to piece together what motivated lamb.
# Predicted translation: das eine eine nicht verbergen.
# Actual translation: einen tag nach der schießerei in der universität, die studenten und dozenten dazu zwang, sich hinter verschlossenen türen zu verstecken, versuchen die behörden immer noch, sich ein bild davon zu verschaffen, was lamb motivierte. <eos>
# -
# Input sentence: the details released by investigators at both ends of the state as well as students and staff who knew him helped paint a picture of a talented but possibly troubled teacher.
# Predicted translation: eine einen einen minuten hinaus.
# Actual translation: die von den ermittlern an beiden enden des staates veröffentlichten details, wie auch das, was studenten und mitarbeiter, die ihn kannten, aussagten, half dabei, ein bild von einem talentierten, aber möglicherweise schwierigen lehrer zu zeichnen. <eos>
# -
# Input sentence: students said they looked forward to his class.
# Predicted translation: eine einen am zu gegangen.
# Actual translation: studenten sagten, dass sie sich auf seinen unterricht freuten. <eos>
# -
# Input sentence: police in gautier, where prentiss died, said he had no history of violence or criminal record.
# Predicted translation: eine einen ein unbefristeteten es.
# Actual translation: die polizei in gautier, wo prentiss starb, sagte, er habe keine geschichte der gewalt oder eine kriminelle vorgeschichte. <eos>
# -
# Input sentence: schmidt himself had included lamb in a book he wrote where he acknowledged the "wonderful people" he shared his academic life with.
# Predicted translation: eine als noch besonders hinaus.
# Actual translation: schmidt selbst hatte lamb in einem von ihm geschriebenen buch erwähnt, in dem er die "wunderbaren menschen" erwähnte, mit denen er sein akademisches leben teilte. <eos>
# -
# Input sentence: both taught in the division of social sciences and history, which lists 17 faculty members, and many students took courses from both.
# Predicted translation: als und noch zu hinaus.
# Actual translation: beide unterrichteten in der abteilung für sozialwissenschaften und geschichte, deren lehrkörper 17 mitglieder umfasst, und viele studenten besuchten kurse von beiden. <eos>
# -
# Input sentence: at the same time, there were some inclinations of problems.
# Predicted translation: das eine noch besonders hinaus.
# Actual translation: zur gleichen zeit gab es einige neigungen zu problematischen verhaltensweisen. <eos>
# -
# Input sentence: a student who praised lamb, brandon beavers, said he also seemed agitated and jittery, "like there was something wrong with him."
# Predicted translation: ich ich nicht nicht herhalten.
# Actual translation: ein student, brandon beavers, der lamb lobte, sagte, er schien auch ein wenig aufgeregt und nervös, "als ob etwas mit ihm falsch sei." <eos>
# -
# Input sentence: another student, mikel sykes, said lamb told him he was dealing with stress at the end of the 2014-15 academic year.
# Predicted translation: einen für als zu hinaus.
# Actual translation: ein anderer student, mikel sykes, sagte, dass lamm ihm erzählt habe, dass er am ende des akademischen jahres 2014-15 mit stress zu tun hatte. <eos>
# -
# Input sentence: lamb had earlier asked delta state university for a medical leave of absence, saying he had a health issue of some sort.
# Predicted translation: die diesem eine dieser lustig.
# Actual translation: lamb hatte zuvor die delta state university um eine beurlaubung aus gesundheitlichen gründen gebeten und dabei gesagt, dass er irgendein gesundheitliches problem habe. <eos>
# -
# Input sentence: this year, he was only teaching two online classes.
# Predicted translation: als als noch darüber hinaus.
# Actual translation: in diesem jahr unterrichtete er nur zwei online-kurse. <eos>
# -
# Input sentence: recent changes in the university's hiring policies meant that the doctorate lamb had worked so hard to earn would not guarantee him an automatic tenure track to become an assistant professor.
# Predicted translation: eine einen den erschienenen abweichen.
# Actual translation: neueste änderungen in der beschäftigungspolitik der universität bedeuteten, dass die promotion, für die lamb so hart gearbeitet hatte, für ihn keine garantie für einen automatischen weg zu einer anstellung als assistant-professor darstellen würde. <eos>
# -
# Input sentence: university president william laforge said he didn't know of any conflict between lamb and schmidt but "obviously there was something in mr. lamb's mind."
# Predicted translation: ich ich nicht nicht übereinstimme.
# Actual translation: universitäts-präsident william laforge sagte, er wisse nichts von einem konflikt zwischen lamb und schmidt, aber "natürlich gab es etwas in mr lambs vorstellung." <eos>
# -
# Input sentence: those are questions lamb can no longer answer.
# Predicted translation: das eine nur am vorbehalt.
# Actual translation: das sind fragen, die lamb nicht mehr beantworten kann. <eos>
# -
# Input sentence: after fleeing the campus, police later picked up lamb's trail when he crossed back into mississippi from arkansas.
# Predicted translation: in als in gleichstellungsfragen abgestellt.
# Actual translation: nach der flucht aus dem campus fand die polizei später lambs spur, als er wieder in mississippi aus arkansas einfuhr. <eos>
# -
# Input sentence: before he could be apprehended, lamb killed himself with a single .38-caliber pistol in the backyard of a home about a mile south of his parents' home on the outskirts of greenville, mississippi, said washington county coroner methel johnson.
# Predicted translation: der an der reform hinaus.
# Actual translation: bevor er festgenommen werden konnte, tötete lamb sich selbstmit einer .38 kaliber pistole im hinterhof eines hauses etwa eine meile südlich seines elternhauses am stadtrand von greenville, mississippi, sagte washington county coroner methel johnson. <eos>
# -
# Input sentence: his car was still running in the driveway.
# Predicted translation: nun und noch zu verbergen.
# Actual translation: sein auto lief noch in der einfahrt. <eos>
# -
# Input sentence: it was not immediately clear why lamb went to that home, though johnson said she believes he knew the people who lived there.
# Predicted translation: das nicht nicht besonders hinaus.
# Actual translation: es war nicht sofort klar, warum lamm zu diesem haus ging, aber johnson sagte, dass sie glaubt, dass er die leute kannte, die dort lebten. <eos>
# -
# Input sentence: lamb grew up in the area.
# Predicted translation: in ist in bereich teilzunehmen.
# Actual translation: lamb wuchs in der gegend auf. <eos>
# -
# Input sentence: lamb started working at the university, which has 3,500 students in a city of about 12,000, in 2009 and taught geography and education classes.
# Predicted translation: und und und zu maximieren.
# Actual translation: lamb begann 2009 seine arbeit an der universität, die 3.500 studenten in einer stadt mit etwa 12.000 einwohnern hat und unterrichtete geographie und pädagogik. <eos>
# -
# Input sentence: he received a doctorate in education in the spring.
# Predicted translation: in im im jahre hört.
# Actual translation: er promovierte im frühjahr in pädagogik. <eos>
# -
# Input sentence: one of lamb's longtime friends described him as smart, charismatic and funny.
# Predicted translation: ihn und und und stellen.
# Actual translation: einer der langjährigen freundinnen lambs bezeichnete ihn als intelligent, charismatisch und lustig. <eos>
# -
# Input sentence: carla hairston said she was 15 and lamb was 20 when they met through mutual friends.
# Predicted translation: das einen nicht am gegangen.
# Actual translation: carla hairston sagte, sie war 15 und lamm war 20, als sie sich durch gemeinsame freunde trafen. <eos>
# -
# Input sentence: she and her friends were in high school, and he was the cool older guy who tried for several years to teach her to play guitar.
# Predicted translation: das einen eine am gegangen.
# Actual translation: sie und ihre freunde waren in der high school, und er war der coole ältere kerl, der einige jahre versuchte, ihr das gitarrenspiel beizubringen. <eos>
# -
# Input sentence: he was quite the heartthrob back then.
# Predicted translation: das ist ist mal gegangen.
# Actual translation: er war damals der frauenschwarm. <eos>
# -
# Input sentence: all the girls would melt when he was around," said hairston, now 40 and living in the jackson suburb of brandon.
# Predicted translation: und als der jahre hinaus.
# Actual translation: alle mädchen schmolzen dahin, wenn er da war", sagte hairston, jetzt 40 und in der jackson vorstadt von brandon wohnhaft. <eos>
# -
# Input sentence: lamb and prentiss had apparently been dating for some time.
# Predicted translation: das eine am wieder gegangen.
# Actual translation: lamb und prentiss waren offensichtlich einige zeit zusammen. <eos>
# -
# Input sentence: in the 911 call, lamb said "i killed my wife," but there was no record of them ever marrying.
# Predicted translation: das wir nicht nicht vorbehalt.
# Actual translation: in dem notruf sagte lamb "ich habe meine frau getötet", aber es gab keine urkunde von einer heirat. <eos>
# -
# Input sentence: they had a dog named lightning that lived with them at the brick house that backs up to a bayou in gautier.
# Predicted translation: das ist eine nicht verbergen.
# Actual translation: sie hatten einen hund namens lightning, der mit ihnen in dem backstein-haus lebte, das an einen bayou in gautier angrenzt. <eos>
# -
# Input sentence: police said the dog was ok.
# Predicted translation: das ist nicht mal gegangen.
# Actual translation: die polizei sagte, dass der hund in ordnung war. <eos>
# -
# Input sentence: prentiss' ex-husband, shawn o'steen, said they divorced 15 years ago but remained friends and had a daughter who's now 19.
# Predicted translation: nur mit nur möglichen abgeschlossen.
# Actual translation: der ex-ehemann von prentiss, shawn o'steen, sagte, sie seien vor 15 jahren geschieden wurden, aber freunde geblieben waren und eine tochter hatten, die jetzt 19 jahre alt war. <eos>
# -
# Input sentence: "she was completely devastated," o'steen said of his daughter.
# Predicted translation: eine als ein brief nichts.
# Actual translation: "sie war total am boden zerstört", sagte o'steen über seine tochter. <eos>
# -
# Input sentence: she and her mother were absolutely best friends.
# Predicted translation: ich hat ich nicht herhalten.
# Actual translation: sie und ihre mutter waren absolut beste freunde. <eos>

# %% [markdown]
# ##Evaluation metric: BLEU Score

# %%
import nltk
pred=[]
for words in test_predicted_sentence:
    pred.append(words.split())

# %%
actual=[]
for words in test_actual_sentence:
    actual.append(words.split())

# %%
from nltk.translate.bleu_score import SmoothingFunction
chencherry = SmoothingFunction()
BLEUscore = nltk.translate.bleu_score.corpus_bleu(actual,pred,smoothing_function=chencherry.method4)
print(BLEUscore)
# Out:
# 0.00035596446627787846

# %%
import sacrebleu
x=sacrebleu.raw_corpus_bleu(test_predicted_sentence,[test_actual_sentence])
print(x)
# Out:
# BLEU = 0.01 12.5/0.1/0.0/0.0 (BP = 0.052 ratio = 0.253 hyp_len = 2491 ref_len = 9839)

# %% [markdown]
# ##Bleu-1 Score

# %%
import evaluate
bleu = evaluate.load("bleu")

results = bleu.compute(predictions=test_predicted_sentence, references=test_actual_sentence,max_order=1)
print(results)
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# {'bleu': 0.011258583014270294, 'precisions': [0.25283144570286475], 'brevity_penalty': 0.044529995005058526, 'length_ratio': 0.24321477760674065, 'translation_length': 3002, 'reference_length': 12343}

# %%
print(results['bleu'])
# Out:
# 0.011258583014270294

# %% [markdown]
# Overall **Bleu-1** score: **0.011258583014270294** over all the samples in the test set

# %% [markdown]
# ##Bleu-2 Score

# %%
import evaluate
bleu = evaluate.load("bleu")

results = bleu.compute(predictions=test_predicted_sentence, references=test_actual_sentence,max_order=2)
print(results)
# Out:
# {'bleu': 0.0008950921766039782, 'precisions': [0.25283144570286475, 0.0015980823012385138], 'brevity_penalty': 0.044529995005058526, 'length_ratio': 0.24321477760674065, 'translation_length': 3002, 'reference_length': 12343}

# %%
print(results['bleu'])
# Out:
# 0.0008950921766039782

# %% [markdown]
# Overall **Bleu-2** score: **0.0008950921766039782** over all the
# samples in the test set

# %% [markdown]
# ##Evaluation metric: Rouge-L Score

# %%
# !pip install evaluate
# !pip install rouge_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: evaluate in /usr/local/lib/python3.9/dist-packages (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from evaluate) (23.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.9/dist-packages (from evaluate) (0.3.6)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from evaluate) (0.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from evaluate) (1.22.4)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from evaluate) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2023.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from evaluate) (1.4.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from evaluate) (3.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (2.27.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from evaluate) (0.13.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from evaluate) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (9.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->evaluate) (3.8.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.7.0->evaluate) (3.10.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->evaluate) (2.0.12)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->evaluate) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rouge_score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.9/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from rouge_score) (1.22.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.9/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->rouge_score) (1.1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->rouge_score) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk->rouge_score) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk->rouge_score) (2022.10.31)
# Building wheels for collected packages: rouge_score
#   Building wheel for rouge_score (setup.py) ... done
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=1d03391efd681fc4f25a3d3570c5278f9ef6388d009c4bd2aac9e4b0a1564803
#   Stored in directory: /root/.cache/pip/wheels/9b/3d/39/09558097d3119ca0a4d462df68f22c6f3c1b345ac63a09b86e
# Successfully built rouge_score
# Installing collected packages: rouge_score
# Successfully installed rouge_score-0.1.2

# %%
import evaluate
r = evaluate.load('rouge')

results = r.compute(predictions=test_predicted_sentence, references=test_actual_sentence)
print(results)
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]
# {'rouge1': 0.05015585699064384, 'rouge2': 0.0006501892674237363, 'rougeL': 0.048446715905866675, 'rougeLsum': 0.04820680861545448}

# %%
print(results['rougeL'])
# Out:
# 0.048446715905866675

# %% [markdown]
# Overall **ROUGE-L** score: **0.048446715905866675** over all the samples in the test set
